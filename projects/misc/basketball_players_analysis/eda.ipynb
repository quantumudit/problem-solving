# %% [markdown]
# # Basketball Players Analysis
#
# Exploring salary and in-game metrics for the top-10 highest paid NBA basketball
# players from 2005 to 2014.

# %% [markdown]
# ## Importing Libraries & Settings

# %%
# import libraries here

# %% [markdown]
# ## Loading Data
#
# Load `basketball_players_data.csv` (generated by `build_dataset.py`) and inspect the first few rows.

# %%
# load data from basketball_players_data.csv and preview the DataFrame

# %% [markdown]
# ## Data Profiling

# %% [markdown]
# ### Shape & Schema

# %%
# check shape, dtypes, and info

# %% [markdown]
# ### Unique Values

# %%
# list unique players

# %%
# list unique measures

# %%
# list unique years

# %% [markdown]
# ### Filtering the DataFrame
#
# Slice the DataFrame to view a specific player's value for a particular measure and year.

# %%
# filter example: view a single player's metric in a given year

# %% [markdown]
# ### Creating a Filter Function
#
# Write a reusable function that returns a single value given a measure, player, and year.

# %%
# define player_year_metric_value(metric, player, year) -> scalar

# %% [markdown]
# ## Visualizing Data
#
# Build two reusable plotting functions:
# - `single_metric_compare(measure_name)` -- compare all players on one raw measure
# - `derived_metric_compare([numerator, denominator])` -- compare all players on a ratio

# %% [markdown]
# ### Player Color and Marker Maps

# %%
# define players_color and players_marker dicts keyed by player name

# %% [markdown]
# ### Single Metric Compare Function

# %%
# define single_metric_compare(measure_name, player_names=players)

# %% [markdown]
# ### Derived Metric Compare Function

# %%
# define derived_metric_compare(measure_names: list, player_names=players)
# measure_names = [numerator_measure, denominator_measure]

# %% [markdown]
# ### Quick Sanity Checks
#
# Test each function with a single call before using them in the analysis scripts.

# %%
# test single_metric_compare with 'Salary'

# %%
# test derived_metric_compare with ['Salary', 'Games Played']
